# %%
import pandas as pd

# %%
"""
1.Select the rows from 20th index till 200th index (exclusive), and columns from 2nd index till
15th index value.
"""

# %%
churn = pd.read_csv("C:\\Users\\black\\Desktop\\PyforDS\\datasets\\customer_churn.csv")

# %%
churn.iloc[20:201, 2:15]
# Out:
#      SeniorCitizen Partner Dependents  tenure PhoneService     MultipleLines  \
# 20               1      No         No       1           No  No phone service
# 21               0     Yes         No      12          Yes                No
# 22               0      No         No       1          Yes                No
# 23               0     Yes         No      58          Yes               Yes
# 24               0     Yes        Yes      49          Yes                No
# ..             ...     ...        ...     ...          ...               ...
# 196              0     Yes        Yes      24          Yes               Yes
# 197              0      No         No      59          Yes               Yes
# 198              0     Yes        Yes      72          Yes               Yes
# 199              0      No        Yes       1          Yes                No
# 200              0     Yes         No      27          Yes                No
#
# ...
